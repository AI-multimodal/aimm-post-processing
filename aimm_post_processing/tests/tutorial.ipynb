# %%
from tiled.client import from_uri
from aimm_post_processing import utils
from aimm_post_processing.operations import *

# %%
client = from_uri("https://aimm.lbl.gov/api")
view = client['dataset']['newville']['uid']['cCv65Ngs86N']

# %% [markdown]
# # Plot raw data

# %%
data0 = view.read()
data0.plot('energy', ['mutrans','mufluor', 'murefer'], ls='', marker='.', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='energy'>

# %% [markdown]
# # Operation: map onto a standard grid

# %%
standardizegrid_operator = StandardizeGrid()
data_dictionary = standardizegrid_operator(
    view, 
    x0=15700, 
    xf=17000, 
    nx=1301,
    x_column="energy",
    y_columns=["mutrans", "mufluor", "murefer"]
)
data1 = data_dictionary['data']
metadata1 = data_dictionary['metadata']

# %%
data.plot('energy', ['mutrans','mufluor', 'murefer'], ls='', marker='.', figsize=(12,4))
# Out:
# <AxesSubplot:xlabel='energy'>
